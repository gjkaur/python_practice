# %% [markdown]
# # M11 – Database & File Processing
#
# **PCPP Alignment**: Section 5 (5.1, 5.2)
# **Professional Focus**: Data persistence, file formats, logging, configuration.
#
# ---
#
# ## Learning Outcomes
#
# - Work with SQLite databases
# - Perform CRUD operations
# - Process CSV files
# - Configure and use logging
# - Parse configuration files
#
# ---

# %% [markdown]
# ## 1. SQLite Database (PCPP 5.1)
#
# Create and query SQLite databases.

# %%
import sqlite3

# Connect to database
conn = sqlite3.connect(':memory:')  # In-memory database
cursor = conn.cursor()

# Create table
cursor.execute("""
    CREATE TABLE users (
        id INTEGER PRIMARY KEY,
        name TEXT NOT NULL,
        email TEXT UNIQUE
    )
""")

# Insert data (parameterized query)
cursor.execute("INSERT INTO users (name, email) VALUES (?, ?)", ("Alice", "alice@example.com"))

# Query data
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()
print(f"Users: {rows}")

conn.commit()
conn.close()

# %% [markdown]
# **Additional Example**: SQLite CREATE and INSERT.

# %%
import sqlite3
conn = sqlite3.connect(':memory:')
conn.execute('CREATE TABLE users (id INTEGER PRIMARY KEY, name TEXT)')
conn.execute('INSERT INTO users (name) VALUES (?)', ('Ada',))
row = conn.execute('SELECT name FROM users').fetchone()
print(row)
conn.close()

# %% [markdown]
# ## 2. CSV Processing (PCPP 5.2)
#
# Read and write CSV files.

# %%
import csv

# Write CSV
with open('data.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['name', 'age'])
    writer.writeheader()
    writer.writerow({'name': 'Alice', 'age': 30})
    writer.writerow({'name': 'Bob', 'age': 25})

# Read CSV
with open('data.csv', 'r', newline='') as f:
    reader = csv.DictReader(f)
    for row in reader:
        print(f"{row['name']}: {row['age']}")

# %% [markdown]
# **Additional Example**: Parameterized query prevents SQL injection.

# %%
import sqlite3
conn = sqlite3.connect(':memory:')
conn.execute('CREATE TABLE items (name TEXT)')
conn.execute('INSERT INTO items VALUES (?)', ('safe',))
user_input = "'; DROP TABLE items; --"
rows = conn.execute('SELECT name FROM items WHERE name = ?', (user_input,)).fetchall()
print('rows:', rows)
conn.close()

# %% [markdown]
# ## 3. Logging (PCPP 5.2)
#
# Configure and use logging module.

# %%
import logging

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

logger = logging.getLogger(__name__)

logger.info("Info message")
logger.warning("Warning message")
logger.error("Error message")

# %% [markdown]
# **Additional Example**: CSV read with csv module.

# %%
import csv
from io import StringIO
text = 'name,score\nAda,90\nBob,85\n'
reader = csv.DictReader(StringIO(text))
print(list(reader))

# %% [markdown]
# ## 4. ConfigParser (PCPP 5.2)
#
# Parse configuration files.

# %%
import configparser

# Create config
config = configparser.ConfigParser()
config['database'] = {'host': 'localhost', 'port': '5432'}

# Write config
with open('config.ini', 'w') as f:
    config.write(f)

# Read config
config_read = configparser.ConfigParser()
config_read.read('config.ini')
print(f"Host: {config_read.get('database', 'host')}")

# %% [markdown]
# **Additional Example**: Context manager for DB connection.

# %%
import sqlite3
from contextlib import closing

with closing(sqlite3.connect(':memory:')) as conn:
    conn.execute('SELECT 1')
    print('connection active inside with block')

# %% [markdown]
# ## Practice Exercises
#
# Complete the exercises in `practice/practice_11_database.py`
